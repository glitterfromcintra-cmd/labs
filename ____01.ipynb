# %% [markdown]
# # Лабораторная работа 1. ПРИНЦИПЫ РАЗРАБОТКИ ПРОГРАММ

# %% [markdown]
# ИНБ-б-о-26-2 Шеломкова Полина

# %% [markdown]
# ## Задание

# %% [markdown]
# ###Первая часть:
# Изменить скрипт, созданный в ходе выполнения данной практической
# работы таким образом, чтобы в блокноте Python Notebook выводилась следующая
# информация (каждый студент должен использовать персональную информацию о
# себе):
# * ФИО студента;
# * группа студента и шифр специальности;
# * перечень языков программирования и ИТ-технологий, которые студент
# считает наиболее перспективными для изучения;
# * краткое описание личных увлечений, хобби, интересов
# ###Вторая часть:
# Необходимо вычислить значение выражения:
# $$A0=\frac{35}{G\_1}\cdot Zvcw + G\_1 \cdot a - \frac{a+Zvcw}{a}$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ##Первая часть индивидуального задания: Вывод персональных данных о себе

# %%
fio = "ФИО - Шеломкова Полина Александровна"
g = "Группа, шифр специальности - ИНБ-б-о-26-2, 10.03.01"
p = "Перечень - 1С, ИИ-технологии (перспективно, но не интересно), сетевая инженерия, информационная (компьютерная, автоматизированных систем) безопасность"
u = "Хобби, увлечения - Рисование, компьютерные игры, музыка"
print(fio)
print(g)
print(p)
print(u)
# Out:
# ФИО - Шеломкова Полина Александровна
# Группа, шифр специальности - ИНБ-б-о-26-2, 10.03.01
# Перечень - 1С, ИИ-технологии (перспективно, но не интересно), сетевая инженерия, информационная (компьютерная, автоматизированных систем) безопасность
# Хобби, увлечения - Рисование, компьютерные игры, музыка

# %% [markdown]
# ## Вторая часть индивидуального задания: Вычисление выражение, печать результатов

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $G\_1, Zvcw, a$. Переменная, которая должна быть вычислена на основе независимых: $A0$.

# %%
G_1=10
Zvcw=30.67
a=5
print("G_1 = ", G_1, ", type(G_1) = ", type(G_1))
print("Zvcw = ", Zvcw, ", type(Zvcw) = ", type(Zvcw))
print("a = ", a, ", type(a) = ", type(a))

# %% [markdown]
# Код для вычисления значения выражения $A0$:

# %%
A0= (35 / G_1) * Zvcw + G_1 * a - (a+Zvcw) / a
print('A0=', A0)
print('Type of A0: ', type(A0))
# Out:
# Z= 3.76386208487326e+26
# Type of Z:  <class 'float'>

# %% [markdown]
# ## Ответы на вопросы

# %% [markdown]
# **1. Чем отличается интерпретируемый язык программирования от
# компилируемого?**
# ##### Интерпритируемый язык программирования обрабатывается интерпритатором, который читает его построчно и автоматически переводит в машинный код, компилируемый же язык программирования обрабатывается компилятором сразу, до запуска программы и после компиляции получается бинарный файл, который можно запускать неограниченное количество раз без повторной обработки
# **2. Перечислите компилируемые языки программирования.**
# ##### Языки семейства C, Pascal
# **3. Перечислите интерпретируемые языки программирования.**
# ##### Python, PHP, JavaScript
# **4. Как объявляется переменные в языке Python?**
# ##### Переменные объявляются при помощи объявления самой переменной и ее значения, переменная может называться только на букву (a-z)(A-Z) или на нижнее подчеркивание, а так же содержать те же символы и цифры (0-9)
# **5. Каким образом определить тип переменной в языке Python?**
# #####Тип переменной определяется автоматически, в зависимости от того что написано в самой переменной
# **6. Для чего используется функция print( ) ?**
# ##### Данная функция используется для вывода результата, переменных и/или строки
# **7. Какая функция предназначена для вычисления модуля в Python? Какую
# библиотеку необходимо для этого подключить?**
# #####Для вычисления модуля есть 2 варианта: 1) Через функцию abs(), является встроенной и не требует подключения каких-либо библиотек или модулей; 2) Через функцию fabs(), для этого требуется использовать встроенный в основную библиотеку Python модуль math
# **8. Какие из перечисленных идентификаторов нельзя использовать в качестве
# имен пользовательских переменных?
# _1_01, b100, int, double_1, _b200, MyVar, create-var, 4perem,
# _5elem, zo0, wodoo, UserCount, system_call, string, System.Double.**
# ##### Нельзя использовать: int, create-var, System.Double
# **9. Перечислите основные типы в Python.**
# ##### int, bool, float, str, list, set, dict
# **10. Как называется программа, которая выполняет специализированную
# задачу, в частности, такие программы, как вирусный сканер, программа сжатия
# файлов или программа резервного копирования данных?**
# ##### Системное программное обеспечение
# **11. К какой категории программного обеспечения принадлежат программы
# обработки текста, программы по работе электронными таблицами, почтовые
# программы, веб-браузеры и компьютерные игры?**
# ##### Прикладное программное обеспечение
# **12. Какого объема памяти достаточно для хранения буквы алфавита или
# небольшого числа?**
# #####Для хранения буквы алфавита/небольшого числа достаточно 1 байта (8 бит)
# **13. В какой системе исчисления все числовые значения записываются как
# последовательности нулей и единиц?**
# ##### В двоичное системе исчисления
# **14. Какова задача схемы кодирования ASCII?**
# #####ASCII создан для унификации обмена текстом между разными устройствами и системами (каждому символу присвоен свой код), но поддерживает только числа, латиницу и незначительное количество спец. символов
# **15. Какая схема кодирования является достаточно широкой, чтобы включать
# символы многих языков мира?**
# #####Unicode является наиболее широкой системой кодирования, может быть совместима с ASCII(UTF-8)
# **16. Что означают термины «цифровые данные» и «цифровое устройство»?**
# ##### Цифровые данные - данные, находящиеся и обрабатывающиеся на
# **17. ЦП понимает инструкции, которые написаны только на одном языке. Как
# называется этот язык?**
# ##### Машинный код, поэтому все программы нужно переводить на него посредством интерпретаторов и компиляторов
# **18. Как называется тип памяти, в которую программа должна копироваться
# при каждом ее исполнении центральным процессором?**
# ##### Оперативная память (ОЗУ)
# **19. Как называется процесс, в котором участвует ЦП, когда он исполняет
# инструкции в программе?**
# #####ЦП участвует в цикле выборки-декодирования-исполнения при исполнении инструкции в прогрмме
# **20. Что такое язык ассемблера?**
# #### Ассемблер - низкоуровневый язык программирования, использует сокращения для простых действий, синтаксис зависит от многих фактором, но смысл остается одним
